# %% [markdown]
# # Grupo 1 - Smog predicition
# ## Decision Tree

# %% [markdown]
# ### Análisis y limipieza de datos

# %%
import numpy as np
import pandas as pd

df = pd.read_csv('data/train.csv')

df['Gears'] = df['Transmission'].str.extract('(\d+)')
df['Gears'] = pd.to_numeric(df['Gears'], errors='coerce')
df['Transmission'] = df['Transmission'].str.extract('(\D+)')

# %%
#Fuel Type
df.loc[df["Fuel Type"] == "X", "Fuel Type"] = 0
df.loc[df["Fuel Type"] == "Z", "Fuel Type"] = 1
df.loc[df["Fuel Type"] == "D", "Fuel Type"] = 2
df.loc[df["Fuel Type"] == "E", "Fuel Type"] = 3
df.loc[df["Fuel Type"] == "N", "Fuel Type"] = 4

#Transmission
df.loc[df["Transmission"] == "A", "Transmission"] = 0
df.loc[df["Transmission"] == "AM", "Transmission"] = 1
df.loc[df["Transmission"] == "AS", "Transmission"] = 2
df.loc[df["Transmission"] == "AV", "Transmission"] = 3
df.loc[df["Transmission"] == "M", "Transmission"] = 4


#Vehicle Class
df.loc[df["Vehicle Class"] == "Compact", "Vehicle Class"] = 0
df.loc[df["Vehicle Class"] == "Full-size", "Vehicle Class"] = 1
df.loc[df["Vehicle Class"] == "Mid-size", "Vehicle Class"] = 2
df.loc[df["Vehicle Class"] == "Minicompact", "Vehicle Class"] = 3
df.loc[df["Vehicle Class"] == "Minivan", "Vehicle Class"] = 4
df.loc[df["Vehicle Class"] == "Minicompact", "Vehicle Class"] = 5
df.loc[df["Vehicle Class"] == "Pickup truck: Small", "Vehicle Class"] = 6
df.loc[df["Vehicle Class"] == "Pickup truck: Standard", "Vehicle Class"] = 7
df.loc[df["Vehicle Class"] == "SUV: Small", "Vehicle Class"] = 8
df.loc[df["Vehicle Class"] == "SUV: Standard", "Vehicle Class"] = 9
df.loc[df["Vehicle Class"] == "Special purpose vehicle", "Vehicle Class"] = 10
df.loc[df["Vehicle Class"] == "Station wagon: Mid-size", "Vehicle Class"] = 11
df.loc[df["Vehicle Class"] == "Station wagon: Small", "Vehicle Class"] = 12
df.loc[df["Vehicle Class"] == "Subcompact", "Vehicle Class"] = 13
df.loc[df["Vehicle Class"] == "Two-seater", "Vehicle Class"] = 14

df['Gears'].fillna(df['Gears'].mean(), inplace=True)

# %%
df.drop("Model Year", axis=1, inplace=True)
df.drop("Make", axis=1, inplace=True)
df.drop("Model", axis=1, inplace=True)
df.drop("Comb (mpg)", axis=1, inplace=True)
df.drop("Fuel Consumption City (L/100 km)", axis=1, inplace=True)
df.drop("Hwy (L/100 km)", axis=1, inplace=True)

df.head()
# Out:
#             id Vehicle Class  Engine Size (L)  Cylinders Transmission  \
# 0  ab44e9bec15            12              2.0          4            1
# 1  45926762371             2              2.0          4            2
# 2  e9be56e153f             1              2.9          6            1
# 3  077092760df             0              2.0          4            2
# 4  c1c2579b795             3              5.2         12            0
#
#   Fuel Type  Comb (L/100 km)  CO2 Emissions (g/km)  Smog  Gears
# 0         1              8.7                   202     2    7.0
# 1         0              7.7                   181     4    6.0
# 2         1             11.7                   274     2    8.0
# 3         0              8.1                   189     1    6.0
# 4         1             13.8                   324     1    8.0

# %% [markdown]
# Con esto, hemos terminado el análisis y la limpieza de los datos del dataframe de entrenamiento.

# %% [markdown]
# ---

# %% [markdown]
# ### División en conjuntos de entrenamiento y prueba

# %%
from sklearn.model_selection import train_test_split

# Features of the model
#features = ['Vehicle Class', 'Engine Size (L)', 'Cylinders', 'Transmission', 'Fuel Type', 'Comb (L/100 km)', 'CO2 Emissions (g/km)', 'Gears']
features = ['Vehicle Class', 'Engine Size (L)', 'Cylinders', 'Transmission', 'Fuel Type', 'CO2 Emissions (g/km)', 'Gears']
# Transform dataframe in numpy arrays
x = df[features].values
y = df['Smog'].values


# Test set will be the 25% taken randomly
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25, random_state=33)

# %% [markdown]
# ### Entrenamiento del modelo

# %%
from sklearn import tree

max_depth=3
random_state=1

model = tree.DecisionTreeClassifier(max_depth=max_depth, random_state=random_state)

model.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=3, random_state=1)

# %% [markdown]
# ---

# %% [markdown]
# En este caso, el modelo a emplear será el de Decision Tree. Emplearemos directamente validación mediante K-Fold a la hora de dividir el conjunto de entrenamiento y así evitar posibles sesgos.

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.pipeline import Pipeline
from sklearn.model_selection import cross_val_score, KFold
from sklearn.preprocessing import StandardScaler

# Features of the model
#features = ['Vehicle Class', 'Engine Size (L)', 'Cylinders', 'Transmission', 'Fuel Type', 'Comb (L/100 km)', 'CO2 Emissions (g/km)', 'Gears']
features = ['Vehicle Class', 'Engine Size (L)', 'Cylinders', 'Transmission', 'Fuel Type', 'CO2 Emissions (g/km)', 'Gears']
# Transform dataframe in numpy arrays
x = df[features].values
y = df['Smog'].values

model = Pipeline([
        ('scaler', StandardScaler()),
        ('DecisionTree', DecisionTreeClassifier())
])

# create a k-fold cross validation iterator of k=10 folds
cv = KFold(10, shuffle=True, random_state=33)

# by default the score used is the one returned by score method of the estimator (accuracy)
scores = cross_val_score(model, x, y, cv=cv)
print(scores)
# Out:
# [0.72881356 0.72881356 0.71186441 0.74576271 0.66101695 0.69491525
#  0.67241379 0.75862069 0.67241379 0.67241379]

# %%
from scipy.stats import sem
def mean_score(scores):
    return ("Mean score: {0:.3f} (+/- {1:.3f})").format(np.mean(scores), sem(scores))
print(mean_score(scores))
# Out:
# Mean score: 0.705 (+/- 0.011)

# %% [markdown]
# ### Ajuste del algoritmo

# %% [markdown]
# A continuación, vamos a realizar un ajuste de los hiperparámetros del algoritmo mediante *grid search*.

# %%
# Set the hyperparameters by cross-validation

from sklearn.metrics import classification_report, recall_score, precision_score, make_scorer
from sklearn.model_selection import GridSearchCV

# set of hyperparameters to test
tuned_hyperparameters = [{'max_depth': np.arange(3, 10),
                     'criterion': ['gini', 'entropy'], 
                     'splitter': ['best', 'random'],
                     'min_samples_leaf': [2, 5, 10],
                     'class_weight':['balanced', None],
                     'max_leaf_nodes': [None, 5, 10, 20]
                    }]

scores = ['precision', 'recall']

for score in scores:
    print("# Tuning hyperparameters for %s" % score)
    print()

    if score == 'precision':
        scorer = make_scorer(precision_score, average='weighted', zero_division=0)
    elif score == 'recall':
        scorer = make_scorer(recall_score, average='weighted', zero_division=0)
    
    # cv = the fold of the cross-validation cv, defaulted to 5
    gs = GridSearchCV(DecisionTreeClassifier(), tuned_hyperparameters, cv=10, scoring=scorer)
    gs.fit(x_train, y_train)

    print("Best hyperparameters set found on development set:")
    print()
    print(gs.best_params_)
    print()
    print("Grid scores on development set:")
    print()
    means = gs.cv_results_['mean_test_score']
    stds = gs.cv_results_['std_test_score']

    for mean_score, std_score, params in zip(means, stds, gs.cv_results_['params']):
        print("%0.3f (+/-%0.03f) for %r" % (mean_score, std_score * 2, params))
    print()

    print("Detailed classification report:")
    print()
    print("The model is trained on the full development set.")
    print("The scores are computed on the full evaluation set.")
    print()
    y_true, y_pred = y_test
for {'class_weight': 'balanced', 'criterion': 'entropy', 'max_depth': 7, 'max_leaf_nodes': 20, 'min_samples_leaf': 5, 'splitter': 'random'}
# 0.549 (+/-0.100) for {'class_weight': 'balanced', 'criterion': 'entropy', 'max_depth': 7, 'max_leaf_nodes': 20, 'min_samples_leaf': 10, 'splitter': 'best'}
# 0.526 (+/-0.146) for {'class_weight': 'balanced', 'criterion': 'entropy', 'max_depth': 7, 'max_leaf_nodes': 20, 'min_samples_leaf': 10, 'splitter': 'random'}
# 0.599 (+/-0.124) for {'class_weight': 'balanced', 'criterion': 'entropy', 'max_depth': 8, 'max_leaf_nodes': None, 'min_samples_leaf': 2, 'splitter': 'best'}
# 0.581 (+/-0.109) for {'class_weight': 'balanced', 'criterion': 'entropy', 'max_depth': 8, 'max_leaf_nodes': None, 'min_samples_leaf': 2, 'splitter': 'random'}
# 0.555 (+/-0.170) for {'class_weight': 'balanced', 'criterion': 'entropy', 'max_depth': 8, 'max_leaf_nodes': None, 'min_samples_leaf': 5, 'splitter': 'best'}
# 0.567 (+/-0.123) for {'class_weight': 'balanced', 'criterion': 'entropy', 'max_depth': 8, 'max_leaf_nodes': None, 'min_samples_leaf': 5, 'splitter': 'random'}
# 0.542 (+/-0.130) for {'class_weight': 'balanced', 'criterion': 'entropy', 'max_depth': 8, 'max_leaf_nodes': None, 'min_samples_leaf': 10, 'splitter': 'best'}
# 0.535 (+/-0.087) for {'class_weight': 'balanced', 'criterion': 'entropy', 'max_depth': 8, 'max_leaf_nodes': None, 'min_samples_leaf': 10, 'splitter': 'random'}
# 0.487 (+/-0.129) for {'class_weight': 'balanced', 'criterion': 'entropy', 'max_depth': 8, 'max_leaf_nodes': 5, 'min_samples_leaf': 2, 'splitter': 'best'}
# 0.371 (+/-0.116) for {'class_weight': 'balanced', 'criterion': 'entropy', 'max_depth': 8, 'max_leaf_nodes': 5, 'min_samples_leaf': 2, 'splitter': 'random'}
# 0.487 (+/-0.129) for {'class_weight': 'balanced', 'criterion': 'entropy', 'max_depth': 8, 'max_leaf_nodes': 5, 'min_samples_leaf': 5, 'splitter': 'best'}
# 0.371 (+/-0.183) for {'class_weight': 'balanced', 'criterion': 'entropy', 'max_depth': 8, 'max_leaf_nodes': 5, 'min_samples_leaf': 5, 'splitter': 'random'}
# 0.487 (+/-0.129) for {'class_weight': 'balanced', 'criterion': 'entropy', 'max_depth': 8, 'max_leaf_nodes': 5, 'min_samples_leaf': 10, 'splitter': 'best'}
# 0.376 (+/-0.175) for {'class_weight': 'balanced', 'criterion': 'entropy', 'max_depth': 8, 'max_leaf_nodes': 5, 'min_samples_leaf': 10, 'splitter': 'random'}
# 0.492 (+/-0.151) for {'class_weight': 'balanced', 'criterion': 'entropy', 'max_depth': 8, 'max_leaf_nodes': 10, 'min_samples_leaf': 2, 'splitter': 'best'}
# 0.497 (+/-0.177) for {'class_weight': 'balanced', 'criterion': 'entropy', 'max_depth': 8, 'max_leaf_nodes': 10, 'min_samples_leaf': 2, 'splitter': 'random'}
# 0.492 (+/-0.151) for {'class_weight': 'balanced', 'criterion': 'entropy', 'max_depth': 8, 'max_leaf_nodes': 10, 'min_samples_leaf': 5, 'splitter': 'best'}
# 0.487 (+/-0.160) for {'class_weight': 'balanced', 'criterion': 'entropy', 'max_depth': 8, 'max_leaf_nodes': 10, 'min_samples_leaf': 5, 'splitter': 'random'}
# 0.496 (+/-0.140) for {'class_weight': 'balanced', 'criterion': 'entropy', 'max_depth': 8, 'max_leaf_nodes': 10, 'min_samples_leaf': 10, 'splitter': 'best'}
# 0.435 (+/-0.133) for {'class_weight': 'balanced', 'criterion': 'entropy', 'max_depth': 8, 'max_leaf_nodes': 10, 'min_samples_leaf': 10, 'splitter': 'random'}
# 0.556 (+/-0.163) for {'class_weight': 'balanced', 'criterion': 'entropy', 'max_depth': 8, 'max_leaf_nodes': 20, 'min_samples_leaf': 2, 'splitter': 'best'}
# 0.581 (+/-0.106) for {'class_weight': 'balanced', 'criterion': 'entropy', 'max_depth': 8, 'max_leaf_nodes': 20, 'min_samples_leaf': 2, 'splitter': 'random'}
# 0.547 (+/-0.119) for {'class_weight': 'balanced', 'criterion': 'entropy', 'max_depth': 8, 'max_leaf_nodes': 20, 'min_samples_leaf': 5, 'splitter': 'best'}
# ...
# 0.562 (+/-0.148) for {'class_weight': None, 'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': 10, 'min_samples_leaf': 5, 'splitter': 'best'}
# 0.540 (+/-0.159) for {'class_weight': None, 'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': 10, 'min_samples_leaf': 5, 'splitter': 'random'}
# 0.562 (+/-0.148) for {'class_weight': None, 'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': 10, 'min_samples_leaf': 10, 'splitter': 'best'}
# 0.526 (+/-0.131) for {'class_weight': None, 'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': 10, 'min_samples_leaf': 10, 'splitter': 'random'}
# 0.574 (+/-0.148) for {'class_weight': None, 'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': 20, 'min_samples_leaf': 2, 'splitter': 'best'}
# 0.549 (+/-0.148) for {'class_weight': None, 'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': 20, 'min_samples_leaf': 2, 'splitter': 'random'}
# 0.551 (+/-0.149) for {'class_weight': None, 'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': 20, 'min_samples_leaf': 5, 'splitter': 'best'}
# 0.540 (+/-0.087) for {'class_weight': None, 'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': 20, 'min_samples_leaf': 5, 'splitter': 'random'}
# 0.535 (+/-0.155) for {'class_weight': None, 'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': 20, 'min_samples_leaf': 10, 'splitter': 'best'}
# 0.515 (+/-0.099) for {'class_weight': None, 'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': 20, 'min_samples_leaf': 10, 'splitter': 'random'}
# 0.572 (+/-0.213) for {'class_weight': None, 'criterion': 'entropy', 'max_depth': 6, 'max_leaf_nodes': None, 'min_samples_leaf': 2, 'splitter': 'best'}
# 0.579 (+/-0.126) for {'class_weight': None, 'criterion': 'entropy', 'max_depth': 6, 'max_leaf_nodes': None, 'min_samples_leaf': 2, 'splitter': 'random'}
# 0.556 (+/-0.165) for {'class_weight': None, 'criterion': 'entropy', 'max_depth': 6, 'max_leaf_nodes': None, 'min_samples_leaf': 5, 'splitter': 'best'}
# 0.551 (+/-0.153) for {'class_weight': None, 'criterion': 'entropy', 'max_depth': 6, 'max_leaf_nodes': None, 'min_samples_leaf': 5, 'splitter': 'random'}
# 0.538 (+/-0.185) for {'class_weight': None, 'criterion': 'entropy', 'max_depth': 6, 'max_leaf_nodes': None, 'min_samples_leaf': 10, 'splitter': 'best'}
# 0.553 (+/-0.182) for {'class_weight': None, 'criterion': 'entropy', 'max_depth': 6, 'max_leaf_nodes': None, 'min_samples_leaf': 10, 'splitter': 'random'}
# 0.540 (+/-0.110) for {'class_weight': None, 'criterion': 'entropy', 'max_depth': 6, 'max_leaf_nodes': 5, 'min_samples_leaf': 2, 'splitter': 'best'}
# 0.446 (+/-0.149) for {'class_weight': None, 'criterion': 'entropy', 'max_depth': 6, 'max_leaf_nodes': 5, 'min_samples_leaf': 2, 'splitter': 'random'}
# 0.540 (+/-0.110) for {'class_weight': None, 'criterion': 'entropy', 'max_depth': 6, 'max_leaf_nodes': 5, 'min_samples_leaf': 5, 'splitter': 'best'}
# 0.485 (+/-0.132) for {'class_weight': None, 'criterion': 'entropy', 'max_depth': 6, 'max_leaf_nodes': 5, 'min_samples_leaf': 5, 'splitter': 'random'}
# 0.540 (+/-0.110) for {'class_weight': None, 'criterion': 'entropy', 'max_depth': 6, 'max_leaf_nodes': 5, 'min_samples_leaf': 10, 'splitter': 'best'}
# 0.499 (+/-0.182) for {'class_weight': None, 'criterion': 'entropy', 'max_depth': 6, 'max_leaf_nodes': 5, 'min_samples_leaf': 10, 'splitter': 'random'}
# 0.565 (+/-0.172) for {'class_weight': None, 'criterion': 'entropy', 'max_depth': 6, 'max_leaf_nodes': 10, 'min_samples_leaf': 2, 'splitter': 'best'}
# 0.528 (+/-0.093) for {'class_weight': None, 'criterion': 'entropy', 'max_depth': 6, 'max_leaf_nodes': 10, 'min_samples_leaf': 2, 'splitter': 'random'}
# 0.565 (+/-0.172) for {'class_weight': None, 'criterion': 'entropy', 'max_depth': 6, 'max_leaf_nodes': 10, 'min_samples_leaf': 5, 'splitter': 'best'}
# 0.531 (+/-0.163) for {'class_weight': None, 'criterion': 'entropy', 'max_depth': 6, 'max_leaf_nodes': 10, 'min_samples_leaf': 5, 'splitter': 'random'}
# 0.556 (+/-0.163) for {'class_weight': None, 'criterion': 'entropy', 'max_depth': 6, 'max_leaf_nodes': 10, 'min_samples_leaf': 10, 'splitter': 'best'}
# 0.549 (+/-0.175) for {'class_weight': None, 'criterion': 'entropy', 'max_depth': 6, 'max_leaf_nodes': 10, 'min_samples_leaf': 10, 'splitter': 'random'}
# 0.578 (+/-0.142) for {'class_weight': None, 'criterion': 'entropy', 'max_depth': 6, 'max_leaf_nodes': 20, 'min_samples_leaf': 2, 'splitter': 'best'}
# 0.562 (+/-0.116) for {'class_weight': None, 'criterion': 'entropy', 'max_depth': 6, 'max_leaf_nodes': 20, 'min_samples_leaf': 2, 'splitter': 'random'}
# 0.585 (+/-0.138) for {'class_weight': None, 'criterion': 'entropy', 'max_depth': 6, 'max_leaf_nodes': 20, 'min_samples_leaf': 5, 'splitter': 'best'}
# 0.530 (+/-0.175) for {'class_weight': None, 'criterion': 'entropy', 'max_depth': 6, 'max_leaf_nodes': 20, 'min_samples_leaf': 5, 'splitter': 'random'}
# 0.531 (+/-0.182) for {'class_weight': None, 'criterion': 'entropy', 'max_depth': 6, 'max_leaf_nodes': 20, 'min_samples_leaf': 10, 'splitter': 'best'}
# 0.521 (+/-0.129) for {'class_weight': None, 'criterion': 'entropy', 'max_depth': 6, 'max_leaf_nodes': 20, 'min_samples_leaf': 10, 'splitter': 'random'}
# 0.601 (+/-0.143) for {'class_weight': None, 'criterion': 'entropy', 'max_depth': 7, 'max_leaf_nodes': None, 'min_samples_leaf': 2, 'splitter': 'best'}
# 0.604 (+/-0.116) for {'class_weight': None, 'criterion': 'entropy', 'max_depth': 7, 'max_leaf_nodes': None, 'min_samples_leaf': 2, 'splitter': 'random'}
# 0.578 (+/-0.147) for {'class_weight': None, 'criterion': 'entropy', 'max_depth': 7, 'max_leaf_nodes': None, 'min_samples_leaf': 5, 'splitter': 'best'}
# 0.585 (+/-0.126) for {'class_weight': None, 'criterion': 'entropy', 'max_depth': 7, 'max_leaf_nodes': None, 'min_samples_leaf': 5, 'splitter': 'random'}
# 0.542 (+/-0.166) for {'class_weight': None, 'criterion': 'entropy', 'max_depth': 7, 'max_leaf_nodes': None, 'min_samples_leaf': 10, 'splitter': 'best'}
# 0.569 (+/-0.173) for {'class_weight': None, 'criterion': 'entropy', 'max_depth': 7, 'max_leaf_nodes': None, 'min_samples_leaf': 10, 'splitter': 'random'}
# 0.540 (+/-0.110) for {'class_weight': None, 'criterion': 'entropy', 'max_depth': 7, 'max_leaf_nodes': 5, 'min_samples_leaf': 2, 'splitter': 'best'}
# 0.510 (+/-0.122) for {'class_weight': None, 'criterion': 'entropy', 'max_depth': 7, 'max_leaf_nodes': 5, 'min_samples_leaf': 2, 'splitter': 'random'}
# 0.540 (+/-0.110) for {'class_weight': None, 'criterion': 'entropy', 'max_depth': 7, 'max_leaf_nodes': 5, 'min_samples_leaf': 5, 'splitter': 'best'}
# 0.483 (+/-0.167) for {'class_weight': None, 'criterion': 'entropy', 'max_depth': 7, 'max_leaf_nodes': 5, 'min_samples_leaf': 5, 'splitter': 'random'}
# 0.540 (+/-0.110) for {'class_weight': None, 'criterion': 'entropy', 'max_depth': 7, 'max_leaf_nodes': 5, 'min_samples_leaf': 10, 'splitter': 'best'}
# 0.523 (+/-0.183) for {'class_weight': None, 'criterion': 'entropy', 'max_depth': 7, 'max_leaf_nodes': 5, 'min_samples_leaf': 10, 'splitter': 'random'}
# 0.556 (+/-0.168) for {'class_weight': None, 'criterion': 'entropy', 'max_depth': 7, 'max_leaf_nodes': 10, 'min_samples_leaf': 2, 'splitter': 'best'}
# 0.512 (+/-0.129) for {'class_weight': None, 'criterion': 'entropy', 'max_depth': 7, 'max_leaf_nodes': 10, 'min_samples_leaf': 2, 'splitter': 'random'}
# 0.556 (+/-0.168) for {'class_weight': None, 'criterion': 'entropy', 'max_depth': 7, 'max_leaf_nodes': 10, 'min_samples_leaf': 5, 'splitter': 'best'}
# 0.549 (+/-0.122) for {'class_weight': None, 'criterion': 'entropy', 'max_depth': 7, 'max_leaf_nodes': 10, 'min_samples_leaf': 5, 'splitter': 'random'}
# 0.551 (+/-0.164) for {'class_weight': None, 'criterion': 'entropy', 'max_depth': 7, 'max_leaf_nodes': 10, 'min_samples_leaf': 10, 'splitter': 'best'}
# 0.535 (+/-0.071) for {'class_weight': None, 'criterion': 'entropy', 'max_depth': 7, 'max_leaf_nodes': 10, 'min_samples_leaf': 10, 'splitter': 'random'}
# 0.585 (+/-0.131) for {'class_weight': None, 'criterion': 'entropy', 'max_depth': 7, 'max_leaf_nodes': 20, 'min_samples_leaf': 2, 'splitter': 'best'}
# 0.549 (+/-0.187) for {'class_weight': None, 'criterion': 'entropy', 'max_depth': 7, 'max_leaf_nodes': 20, 'min_samples_leaf': 2, 'splitter': 'random'}
# 0.576 (+/-0.121) for {'class_weight': None, 'criterion': 'entropy', 'max_depth': 7, 'max_leaf_nodes': 20, 'min_samples_leaf': 5, 'splitter': 'best'}
# 0.587 (+/-0.121) for {'class_weight': None, 'criterion': 'entropy', 'max_depth': 7, 'max_leaf_nodes': 20, 'min_samples_leaf': 5, 'splitter': 'random'}
# 0.549 (+/-0.155) for {'class_weight': None, 'criterion': 'entropy', 'max_depth': 7, 'max_leaf_nodes': 20, 'min_samples_leaf': 10, 'splitter': 'best'}
# 0.545 (+/-0.128) for {'class_weight': None, 'criterion': 'entropy', 'max_depth': 7, 'max_leaf_nodes': 20, 'min_samples_leaf': 10, 'splitter': 'random'}
# 0.622 (+/-0.167) for {'class_weight': None, 'criterion': 'entropy', 'max_depth': 8, 'max_leaf_nodes': None, 'min_samples_leaf': 2, 'splitter': 'best'}
# 0.601 (+/-0.150) for {'class_weight': None, 'criterion': 'entropy', 'max_depth': 8, 'max_leaf_nodes': None, 'min_samples_leaf': 2, 'splitter': 'random'}
# 0.576 (+/-0.130) for {'class_weight': None, 'criterion': 'entropy', 'max_depth': 8, 'max_leaf_nodes': None, 'min_samples_leaf': 5, 'splitter': 'best'}
# 0.583 (+/-0.117) for {'class_weight': None, 'criterion': 'entropy', 'max_depth': 8, 'max_leaf_nodes': None, 'min_samples_leaf': 5, 'splitter': 'random'}
# 0.540 (+/-0.163) for {'class_weight': None, 'criterion': 'entropy', 'max_depth': 8, 'max_leaf_nodes': None, 'min_samples_leaf': 10, 'splitter': 'best'}
# 0.567 (+/-0.165) for {'class_weight': None, 'criterion': 'entropy', 'max_depth': 8, 'max_leaf_nodes': None, 'min_samples_leaf': 10, 'splitter': 'random'}
# 0.540 (+/-0.110) for {'class_weight': None, 'criterion': 'entropy', 'max_depth': 8, 'max_leaf_nodes': 5, 'min_samples_leaf': 2, 'splitter': 'best'}
# 0.476 (+/-0.159) for {'class_weight': None, 'criterion': 'entropy', 'max_depth': 8, 'max_leaf_nodes': 5, 'min_samples_leaf': 2, 'splitter': 'random'}
# 0.540 (+/-0.110) for {'class_weight': None, 'criterion': 'entropy', 'max_depth': 8, 'max_leaf_nodes': 5, 'min_samples_leaf': 5, 'splitter': 'best'}
# 0.478 (+/-0.137) for {'class_weight': None, 'criterion': 'entropy', 'max_depth': 8, 'max_leaf_nodes': 5, 'min_samples_leaf': 5, 'splitter': 'random'}
# 0.540 (+/-0.110) for {'class_weight': None, 'criterion': 'entropy', 'max_depth': 8, 'max_leaf_nodes': 5, 'min_samples_leaf': 10, 'splitter': 'best'}
# 0.483 (+/-0.125) for {'class_weight': None, 'criterion': 'entropy', 'max_depth': 8, 'max_leaf_nodes': 5, 'min_samples_leaf': 10, 'splitter': 'random'}
# 0.556 (+/-0.168) for {'class_weight': None, 'criterion': 'entropy', 'max_depth': 8, 'max_leaf_nodes': 10, 'min_samples_leaf': 2, 'splitter': 'best'}
# 0.544 (+/-0.148) for {'class_weight': None, 'criterion': 'entropy', 'max_depth': 8, 'max_leaf_nodes': 10, 'min_samples_leaf': 2, 'splitter': 'random'}
# 0.556 (+/-0.168) for {'class_weight': None, 'criterion': 'entropy', 'max_depth': 8, 'max_leaf_nodes': 10, 'min_samples_leaf': 5, 'splitter': 'best'}
# 0.556 (+/-0.117) for {'class_weight': None, 'criterion': 'entropy', 'max_depth': 8, 'max_leaf_nodes': 10, 'min_samples_leaf': 5, 'splitter': 'random'}
# 0.551 (+/-0.164) for {'class_weight': None, 'criterion': 'entropy', 'max_depth': 8, 'max_leaf_nodes': 10, 'min_samples_leaf': 10, 'splitter': 'best'}
# 0.520 (+/-0.117) for {'class_weight': None, 'criterion': 'entropy', 'max_depth': 8, 'max_leaf_nodes': 10, 'min_samples_leaf': 10, 'splitter': 'random'}
# 0.588 (+/-0.129) for {'class_weight': None, 'criterion': 'entropy', 'max_depth': 8, 'max_leaf_nodes': 20, 'min_samples_leaf': 2, 'splitter': 'best'}
# 0.565 (+/-0.175) for {'class_weight': None, 'criterion': 'entropy', 'max_depth': 8, 'max_leaf_nodes': 20, 'min_samples_leaf': 2, 'splitter': 'random'}
# 0.583 (+/-0.118) for {'class_weight': None, 'criterion': 'entropy', 'max_depth': 8, 'max_leaf_nodes': 20, 'min_samples_leaf': 5, 'splitter': 'best'}
# 0.556 (+/-0.128) for {'class_weight': None, 'criterion': 'entropy', 'max_depth': 8, 'max_leaf_nodes': 20, 'min_samples_leaf': 5, 'splitter': 'random'}
# 0.544 (+/-0.158) for {'class_weight': None, 'criterion': 'entropy', 'max_depth': 8, 'max_leaf_nodes': 20, 'min_samples_leaf': 10, 'splitter': 'best'}
# 0.549 (+/-0.130) for {'class_weight': None, 'criterion': 'entropy', 'max_depth': 8, 'max_leaf_nodes': 20, 'min_samples_leaf': 10, 'splitter': 'random'}
# 0.622 (+/-0.149) for {'class_weight': None, 'criterion': 'entropy', 'max_depth': 9, 'max_leaf_nodes': None, 'min_samples_leaf': 2, 'splitter': 'best'}
# 0.620 (+/-0.136) for {'class_weight': None, 'criterion': 'entropy', 'max_depth': 9, 'max_leaf_nodes': None, 'min_samples_leaf': 2, 'splitter': 'random'}
# 0.576 (+/-0.126) for {'class_weight': None, 'criterion': 'entropy', 'max_depth': 9, 'max_leaf_nodes': None, 'min_samples_leaf': 5, 'splitter': 'best'}
# 0.604 (+/-0.107) for {'class_weight': None, 'criterion': 'entropy', 'max_depth': 9, 'max_leaf_nodes': None, 'min_samples_leaf': 5, 'splitter': 'random'}
# 0.547 (+/-0.164) for {'class_weight': None, 'criterion': 'entropy', 'max_depth': 9, 'max_leaf_nodes': None, 'min_samples_leaf': 10, 'splitter': 'best'}
# 0.519 (+/-0.172) for {'class_weight': None, 'criterion': 'entropy', 'max_depth': 9, 'max_leaf_nodes': None, 'min_samples_leaf': 10, 'splitter': 'random'}
# 0.540 (+/-0.110) for {'class_weight': None, 'criterion': 'entropy', 'max_depth': 9, 'max_leaf_nodes': 5, 'min_samples_leaf': 2, 'splitter': 'best'}
# 0.483 (+/-0.181) for {'class_weight': None, 'criterion': 'entropy', 'max_depth': 9, 'max_leaf_nodes': 5, 'min_samples_leaf': 2, 'splitter': 'random'}
# 0.540 (+/-0.110) for {'class_weight': None, 'criterion': 'entropy', 'max_depth': 9, 'max_leaf_nodes': 5, 'min_samples_leaf': 5, 'splitter': 'best'}
# 0.499 (+/-0.117) for {'class_weight': None, 'criterion': 'entropy', 'max_depth': 9, 'max_leaf_nodes': 5, 'min_samples_leaf': 5, 'splitter': 'random'}
# 0.540 (+/-0.110) for {'class_weight': None, 'criterion': 'entropy', 'max_depth': 9, 'max_leaf_nodes': 5, 'min_samples_leaf': 10, 'splitter': 'best'}
# 0.503 (+/-0.189) for {'class_weight': None, 'criterion': 'entropy', 'max_depth': 9, 'max_leaf_nodes': 5, 'min_samples_leaf': 10, 'splitter': 'random'}
# 0.556 (+/-0.168) for {'class_weight': None, 'criterion': 'entropy', 'max_depth': 9, 'max_leaf_nodes': 10, 'min_samples_leaf': 2, 'splitter': 'best'}
# 0.549 (+/-0.104) for {'class_weight': None, 'criterion': 'entropy', 'max_depth': 9, 'max_leaf_nodes': 10, 'min_samples_leaf': 2, 'splitter': 'random'}
# 0.556 (+/-0.168) for {'class_weight': None, 'criterion': 'entropy', 'max_depth': 9, 'max_leaf_nodes': 10, 'min_samples_leaf': 5, 'splitter': 'best'}
# 0.508 (+/-0.121) for {'class_weight': None, 'criterion': 'entropy', 'max_depth': 9, 'max_leaf_nodes': 10, 'min_samples_leaf': 5, 'splitter': 'random'}
# 0.551 (+/-0.164) for {'class_weight': None, 'criterion': 'entropy', 'max_depth': 9, 'max_leaf_nodes': 10, 'min_samples_leaf': 10, 'splitter': 'best'}
# 0.542 (+/-0.075) for {'class_weight': None, 'criterion': 'entropy', 'max_depth': 9, 'max_leaf_nodes': 10, 'min_samples_leaf': 10, 'splitter': 'random'}
# 0.592 (+/-0.138) for {'class_weight': None, 'criterion': 'entropy', 'max_depth': 9, 'max_leaf_nodes': 20, 'min_samples_leaf': 2, 'splitter': 'best'}
# 0.608 (+/-0.153) for {'class_weight': None, 'criterion': 'entropy', 'max_depth': 9, 'max_leaf_nodes': 20, 'min_samples_leaf': 2, 'splitter': 'random'}
# 0.583 (+/-0.118) for {'class_weight': None, 'criterion': 'entropy', 'max_depth': 9, 'max_leaf_nodes': 20, 'min_samples_leaf': 5, 'splitter': 'best'}
# 0.560 (+/-0.095) for {'class_weight': None, 'criterion': 'entropy', 'max_depth': 9, 'max_leaf_nodes': 20, 'min_samples_leaf': 5, 'splitter': 'random'}
# 0.549 (+/-0.153) for {'class_weight': None, 'criterion': 'entropy', 'max_depth': 9, 'max_leaf_nodes': 20, 'min_samples_leaf': 10, 'splitter': 'best'}
# 0.546 (+/-0.128) for {'class_weight': None, 'criterion': 'entropy', 'max_depth': 9, 'max_leaf_nodes': 20, 'min_samples_leaf': 10, 'splitter': 'random'}

# %% [markdown]
# ### Comprobación con el algoritmo ajustado

# %%
# create a composite estimator made by a pipeline of preprocessing and the KNN model
model = Pipeline([
        ('scaler', StandardScaler()),
        ('ds', DecisionTreeClassifier(**gs.best_params_))
])

# Fit the model
model.fit(x_train, y_train) 

# create a k-fold cross validation iterator of k=10 folds
cv = KFold(10, shuffle=True, random_state=33)

# by default the score used is the one returned by score method of the estimator (accuracy)
scores = cross_val_score(model, x, y, cv=cv)
def mean_score(scores):
    return ("Mean score: {0:.3f} (+/- {1:.3f})").format(np.mean(scores), sem(scores))
print(mean_score(scores))
# Out:
# Mean score: 0.674 (+/- 0.016)
